# %% [markdown]
# <a href="https://colab.research.google.com/github/jeffheaton/app_generative_ai/blob/main/t81_559_class_05_3_pydantic.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # T81-559: Applications of Generative Artificial Intelligence
# **Module 5: LangChain: Data Extraction**
# * Instructor: [Jeff Heaton](https://sites.wustl.edu/jeffheaton/), McKelvey School of Engineering, [Washington University in St. Louis](https://engineering.wustl.edu/Programs/Pages/default.aspx)
# * For more information visit the [class website](https://github.com/jeffheaton/app_generative_ai).

# %% [markdown]
# # Module 5 Material
#
# * Part 5.1: The Structured Output Problem [[Video]](https://www.youtube.com/watch?v=62CSR141VRE) [[Notebook]](t81_559_class_05_1_langchain_data.ipynb)
# * Part 5.2: Designing Schemas with Pydantic [[Video]](https://www.youtube.com/watch?v=VXm8gPzU3qc) [[Notebook]](t81_559_class_05_2_parsers.ipynb)
# * **Part 5.3: Validation, Retries, and Refusals** [[Video]](https://www.youtube.com/watch?v=dc4fn-W60hg) [[Notebook]](t81_559_class_05_3_pydantic.ipynb)
# * Part 5.4: Structured Extraction at Scale [[Video]](https://www.youtube.com/watch?v=jBpkAblQC_U) [[Notebook]](t81_559_class_05_4_custom_parsers.ipynb)
# * Part 5.5: Structured Output Under the Hood [[Video]](https://www.youtube.com/watch?v=_txWiLjf4bo) [[Notebook]](t81_559_class_05_5_output_fixing_parsers.ipynb)

# %% [markdown]
# # Google CoLab Instructions
#
# The following code ensures that Google CoLab is running and maps Google Drive if needed.

# %%
import os

try:
    from google.colab import drive, userdata
    COLAB = True
    print("Note: using Google CoLab")
except:
    print("Note: not using Google CoLab")
    COLAB = False

# OpenAI Secrets
if COLAB:
    os.environ["OPENAI_API_KEY"] = userdata.get('OPENAI_API_KEY')

# Install needed libraries in CoLab
if COLAB:
    # !pip install langchain langchain_openai
# Out:
# Note: using Google CoLab
# ...

# %% [markdown]
# # 5.3: Validation, Retries, and Refusals
#
# Structured output gives you an ironclad guarantee about *shape*: the object you receive matches the schema, with the right fields and the right types. It gives you no guarantee at all about *truth*. A model can hallucinate inside a perfectly valid schema -- a confident `year` that is wrong, an `email` that was never in the source text.
#
# Production systems therefore add layers on top of schema enforcement: semantic validation you write yourself, bounded retry loops when validation fails, and graceful handling for the cases where the model refuses or the call errors. This part builds each layer.

# %%
from langchain_openai import ChatOpenAI

MODEL = 'gpt-5.6-luna'

llm = ChatOpenAI(model=MODEL)

# %% [markdown]
# ## Schema-Valid Does Not Mean Correct
#
# The following schema demands publication details for a book. Ask about a book that does not exist, and the model may still return a plausible-looking, fully validated object. The schema did its job; the *facts* are the problem. Run it and inspect the answer skeptically.

# %%
from typing import Optional
from pydantic import BaseModel, Field

class BookInfo(BaseModel):
    """Publication details for a book."""
    title: str
    author: str
    publisher: Optional[str] = None
    year: Optional[int] = None

structured_llm = llm.with_structured_output(BookInfo)
book = structured_llm.invoke(
    "Give publication details for the novel 'The Cartographer's Lament' by Elena Vasquez."
)
print(book)
print("\nEvery field above validated against the schema -- but the book is invented.")

# %% [markdown]
# Marking fields `Optional` helps (it gives the model room to leave unknown values empty), and newer models are better about declining to invent -- but the lesson stands: **validation checks structure, not reality.** When facts matter, ground the model with retrieval (Module 6) or verify against an external source.
#
# ## Field Constraints and Custom Validators
#
# Pydantic lets you attach *semantic* rules to a schema: numeric ranges, and arbitrary Python checks via `field_validator`. These rules run on every object -- whether it came from a model or from your own code. The following demonstrates the machinery deterministically, with no LLM involved, by constructing a bad object by hand.

# %%
from pydantic import ValidationError, field_validator

class SafeMovie(BaseModel):
    """A movie with sanity-checked fields."""
    title: str
    year: int = Field(ge=1888, description="Year of first theatrical release")

    @field_validator("year")
    @classmethod
    def year_not_in_future(cls, v):
        if v > 2030:
            raise ValueError(f"{v} is in the future; use the original release year")
        return v

try:
    SafeMovie(title="Space Epic 9", year=3000)
except ValidationError as e:
    print("Validation failed, as it should:\n")
    print(e)

# %% [markdown]
# Notice the error message: it names the field, the rule, and the offending value. That message is not just for humans -- it is exactly the feedback a model needs to correct itself, which brings us to retries.
#
# ## The Retry Loop
#
# Earlier versions of LangChain shipped an `OutputFixingParser` that caught parse failures and asked the model to repair its own output. With native structured output, malformed JSON has essentially disappeared -- but *your validators* can still reject a response, and the fix is the same idea, now simple enough to write yourself: catch the `ValidationError`, show it to the model, and try again a bounded number of times.

# %%
def extract_with_retry(llm, schema, prompt, max_retries=2):
    """Invoke with structured output; on validation failure, feed the error back."""
    structured = llm.with_structured_output(schema)
    messages = [{"role": "user", "content": prompt}]
    for attempt in range(1, max_retries + 2):
        try:
            result = structured.invoke(messages)
            print(f"(succeeded on attempt {attempt})")
            return result
        except ValidationError as e:
            print(f"(attempt {attempt} failed validation; retrying)")
            messages.append({"role": "user", "content":
                f"Your previous answer failed validation:\n{e}\n"
                f"Correct the problem and answer again."})
    raise RuntimeError(f"No valid response after {max_retries + 1} attempts")

movie = extract_with_retry(
    llm, SafeMovie,
    "Recommend one classic science fiction movie."
)
print(movie)

# %% [markdown]
# Most runs succeed on the first attempt -- modern models respect schemas and constraints well -- and the loop exists for the runs that do not. Two properties make this production-worthy: the retry count is **bounded** (no infinite loops, no runaway spend), and the model receives the **actual error text** rather than a vague "try again."
#
# ## Refusals and Defensive Wrappers
#
# Two more failure modes remain. The model may *refuse* a request that trips its safety policies, and the network or API may simply error. Neither should crash a pipeline that is processing ten thousand records. The standard pattern wraps extraction in a function that always returns, reporting either a result or a reason.

# %%
def safe_extract(llm, schema, prompt, max_retries=1):
    """Returns (result, error). Exactly one of the two is None."""
    try:
        return extract_with_retry(llm, schema, prompt, max_retries), None
    except ValidationError as e:
        return None, f"validation: {str(e).splitlines()[0]}"
    except Exception as e:
        # Covers refusals surfaced as errors, rate limits, and network failures
        return None, f"{type(e).__name__}: {e}"

result, error = safe_extract(llm, SafeMovie, "Recommend one classic western movie.")
if result:
    print("OK:", result)
else:
    print("Failed:", error)

# %% [markdown]
# In a batch job, the `error` strings become a column in your results: you process everything, then triage the failures instead of dying on record 4,317. You will use exactly this discipline in the next part, where we extract structured records from five hundred documents.
#
# ## Summary
#
# * The schema guarantees **shape**; it cannot guarantee **truth**. Ground or verify facts that matter.
# * `Field` constraints and `field_validator` encode your domain rules; their error messages are model-readable.
# * A **bounded retry loop** that feeds the validation error back replaces the old fixing parsers in a dozen lines you control.
# * A **defensive wrapper** that returns `(result, error)` keeps batch pipelines alive.

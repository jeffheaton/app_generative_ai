# %% [markdown]
# <a href="https://colab.research.google.com/github/jeffheaton/app_generative_ai/blob/main/t81_559_class_13_4_speechbot.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # T81-559: Applications of Generative Artificial Intelligence
# **Module 13: Speech Processing**
# * Instructor: [Jeff Heaton](https://sites.wustl.edu/jeffheaton/), McKelvey School of Engineering, [Washington University in St. Louis](https://engineering.wustl.edu/Programs/Pages/default.aspx)
# * For more information visit the [class website](https://github.com/jeffheaton/app_generative_ai).

# %% [markdown]
# # Module 13 Material
#
# Module 13: Speech Processing
#
# * Part 13.1: Intro to Speech Processing [[Notebook]](t81_559_class_13_1_speech_models.ipynb)
# * Part 13.2: Text to Speech [[Notebook]](t81_559_class_13_2_text2speech.ipynb)
# * Part 13.3: Speech to Text [[Notebook]](t81_559_class_13_3_speech2text.ipynb)
# * **Part 13.4: Speech Bot** [[Notebook]](t81_559_class_13_4_speechbot.ipynb)
# * Part 13.5: Future Directions in GenAI [[Notebook]](t81_559_class_13_5_future.ipynb)

# %% [markdown]
# # Google CoLab Instructions
#
# The following code ensures that Google CoLab is running and maps Google Drive if needed.

# %%
import os

try:
    from google.colab import drive, userdata
    COLAB = True
    print("Note: using Google CoLab")
except:
    print("Note: not using Google CoLab")
    COLAB = False

# OpenAI Secrets
if COLAB:
    os.environ["OPENAI_API_KEY"] = userdata.get('OPENAI_API_KEY')

# Install needed libraries in CoLab
if COLAB:
    # !pip install langchain langchain_openai openai pydub

# %% [markdown]
# # Part 13.4: Speech Bot
#
# In this part we will create a speech chat bot. You will talk to it with your own voice and it will respond in voice. We will use the ChatBot object previously introduced.

# %%
from langchain_openai import ChatOpenAI
from langchain_core.prompts import PromptTemplate
from IPython.display import display_markdown
import pickle

DEFAULT_TEMPLATE = """You are a helpful assistant. DO not use markdown, just regular text.
limit your response to just a few sentences. If the user says something that indicates
that they wish to end the chat return just "bye" (no quotes), so I can end the loop.

Current conversation:
{history}
Human: {input}
AI:"""

# Earlier versions of this class used LangChain's ConversationSummaryMemory and
# ConversationChain; those classes moved to the legacy langchain-classic package
# in LangChain 1.0, so the summary memory is implemented directly here.
SUMMARY_TEMPLATE = """Progressively summarize the conversation below, keeping every
fact that might matter later (names, preferences, decisions). Return only the
updated summary, no extra text.

Current summary:
{summary}

New exchange:
Human: {input}
AI: {output}"""

MODEL = 'gpt-5.6-luna'

class ChatBot:
    def __init__(self, llm_chat, llm_summary, template):
        """
        Initializes the ChatBot with language models and a template for conversation.

        :param llm_chat: A large language model for handling chat responses.
        :param llm_summary: A large language model for summarizing conversations.
        :param template: A string template defining the conversation structure.
        """
        self.llm_chat = llm_chat
        self.llm_summary = llm_summary
        self.template = template
        self.prompt_template = PromptTemplate(input_variables=["history", "input"], template=self.template)
        self.summary_template = PromptTemplate(input_variables=["summary", "input", "output"], template=SUMMARY_TEMPLATE)

        # The running conversation summary serves as the bot's memory.
        self.summary = ""
        self.history = []

    def converse(self, prompt):
        """
        Processes a conversation prompt and updates the internal history and memory.

        :param prompt: The input prompt from the user.
        :return: The generated response from the language model.
        """
        self.history.append([self.summary, prompt])
        filled = self.prompt_template.format(history=self.summary, input=prompt)
        output = self.llm_chat.invoke(filled).content

        # Update the running summary with this exchange.
        summary_prompt = self.summary_template.format(
            summary=self.summary, input=prompt, output=output)
        self.summary = self.llm_summary.invoke(summary_prompt).content
        return output

    def chat(self, prompt):
        """
        Handles the full cycle of receiving a prompt, processing it, and displaying the result.

        :param prompt: The input prompt from the user.
        """
        print(f"Human: {prompt}")
        output = self.converse(prompt)
        display_markdown(output, raw=True)

    def print_memory(self):
        """
        Displays the current state of the conversation memory.
        """
        print("**Memory:")
        print(self.summary)

    def clear_memory(self):
        """
        Clears the conversation memory.
        """
        self.summary = ""

    def undo(self):
        """
        Reverts the conversation memory to the state before the last interaction.
        """
        if len(self.history) > 0:
            self.summary = self.history.pop()[0]
        else:
            print("Nothing to undo.")

    def regenerate(self):
        """
        Re-executes the last undone interaction, effectively redoing an undo operation.
        """
        if len(self.history) > 0:
            self.summary, prompt = self.history.pop()
            self.chat(prompt)
        else:
            print("Nothing to regenerate.")

    def save_history(self, file_path):
        """
        Saves the conversation history to a file using pickle.

        :param file_path: The file path where the history should be saved.
        """
        with open(file_path, 'wb') as f:
            pickle.dump(self.history, f)

    def load_history(self, file_path):
        """
        Loads the conversation history from a file using pickle.

        :param file_path: The file path from which to load the history.
        """
        with open(file_path, 'rb') as f:
            self.history = pickle.load(f)
            # Optionally reset the memory based on the last saved state
            if self.history:
                self.summary = self.history[-1][0]

# %% [markdown]
# Next we create a LLM to communicate.

# %%
MODEL = 'gpt-5.6-luna'

# Initialize the OpenAI LLM with your API key
llm = ChatOpenAI(
  model=MODEL,
  temperature= 0.3,
  n= 1)

c = ChatBot(llm, llm, DEFAULT_TEMPLATE)

response = c.converse("Hello, my name is Jeff.")
print(response)

# %% [markdown]
# We previously introduced the code used to record.

# %%
from IPython.display import Javascript, Audio, display, HTML
from google.colab import output
from base64 import b64decode
import io
import time
import uuid
from openai import OpenAI

client = OpenAI()

RECORD_HTML = """
<button id="btn___ID__">Start recording (__SECS__ seconds)</button>
<span id="status___ID__"></span>
<script>
window._rec___ID__ = null;
document.getElementById('btn___ID__').onclick = async () => {
  const btn = document.getElementById('btn___ID__');
  const status = document.getElementById('status___ID__');
  btn.disabled = true;
  try {
    const stream = await navigator.mediaDevices.getUserMedia({audio: true});
    status.textContent = ' Recording...';
    const recorder = new MediaRecorder(stream);
    const chunks = [];
    recorder.ondataavailable = e => chunks.push(e.data);
    recorder.onstop = () => {
      const reader = new FileReader();
      reader.onloadend = () => { window._rec___ID__ = reader.result; status.textContent = ' Done.'; };
      reader.readAsDataURL(new Blob(chunks));
      stream.getTracks().forEach(t => t.stop());
    };
    recorder.start();
    setTimeout(() => recorder.stop(), __MS__);
  } catch (err) {
    window._rec___ID__ = 'ERROR: ' + err;
    status.textContent = ' ' + err;
  }
};
</script>"""

def generate_text(text):
    response = client.audio.speech.create(
        model="gpt-4o-mini-tts",
        voice="nova",
        input=text
    )
    audio_data = response.content
    return audio_data  # Return the audio data directly

def speak_text(text):
    audio_data = generate_text(text)

    # Generate a unique ID for this audio element
    audio_id = f"audio_{uuid.uuid4().hex}"

    # Display the audio with the unique ID
    display(Audio(audio_data, autoplay=True, element_id=audio_id))

    # Create a hidden div to store the audio status
    status_div = f'<div id="{audio_id}_status" style="display: none;">playing</div>'
    display(HTML(status_div))

    # JavaScript to handle audio playback and status
    js_code = f"""
    var audioElement = document.getElementById('{audio_id}');
    if (audioElement) {{
        audioElement.onended = function() {{
            document.getElementById('{audio_id}_status').textContent = 'finished';
        }};
    }}
    """

    # Execute the JavaScript
    display(HTML(f"<script>{js_code}</script>"))

    # Wait for the audio to finish
    while True:
        status = eval_js(f"document.getElementById('{audio_id}_status').textContent")
        if status == 'finished':
            break
        time.sleep(0.1)

def eval_js(js_code):
    from google.colab import output
    return output.eval_js(js_code)

def record(seconds=3):
    rec_id = uuid.uuid4().hex
    html = (RECORD_HTML
            .replace("__ID__", rec_id)
            .replace("__SECS__", str(seconds))
            .replace("__MS__", str(seconds * 1000)))
    display(HTML(html))
    print("Click the button above, allow microphone access, and speak.")
    while True:
        data = output.eval_js(f"window._rec_{rec_id}")
        if data:
            break
        time.sleep(0.3)
    if str(data).startswith("ERROR:"):
        raise RuntimeError(f"Recording failed: {data}")
    binary = b64decode(data.split(",")[1])
    audio = AudioSegment.from_file(io.BytesIO(binary), format="webm")
    audio.export("recorded_audio.wav", format="wav")
    print("Recording done.")
    return audio

def transcribe_audio(filename):
    with open(filename, "rb") as audio_file:
        transcription = client.audio.transcriptions.create(
            model="gpt-4o-transcribe",
            file=audio_file
        )
    return transcription.text

# %% [markdown]
# We now continue the chat conversation until the user requests it to end.

# %%
from pydub import AudioSegment

MODEL = 'gpt-5.6-luna'

# Initialize the OpenAI LLM with your API key
llm = ChatOpenAI(
  model=MODEL,
  temperature= 0.3,
  n= 1)

c = ChatBot(llm, llm, DEFAULT_TEMPLATE)

# Transcribe the recorded audio
response = None
while response != "bye":
    audio = record(5)
    transcription = transcribe_audio("recorded_audio.wav")
    print(f"Human: {transcription}")
    response = c.converse(transcription)
    print(f"AI: {response}")
    speak_text(response)
